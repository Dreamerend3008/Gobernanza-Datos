# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv("../dataFrames/OriginalDataFrame/EAC.csv", sep=';')
df.head()
# Out:
#        V1 CORRELA_16    CORRE_9  IDOJ1   IDAIO CIMREP    BRUTA     CONSUI  \
# 0  987664   4711-472    471-472   11.0  1986.0      0   603028   112214,5
# 1  987666        462    462-463   14.0  1996.0      0  1083695      77336
# 2  987667  4771-4751  476 - 477    4.0  1991.0      0   190661      26863
# 3  987668        466    466-469   14.0  1986.0      0  2459238  1262835,5
# 4  987669        473        473    5.0  2004.0      0  1688361   218895,5
#
#    GAS EMPAQUE  ...   INVINI   INVFIN  ROTACION    INVPRO       CTO    CTOINS  \
# 0    0       0  ...  2409090  2499584   4837343   2454337   4837343   4837343
# 1  780    2970  ...     3193   476400   4820346  239796,5   4820346   4820346
# 2    0       0  ...   431759   422759    515488    427259    515488    515488
# 3    0       0  ...  1963161  2694017  13114471   2328589  13114471  13114471
# 4    0       0  ...   141377   172460   7766200  156918,5   7766200   7766200
#
#   VENTASNOP    GASTOS GASTOSNOP GASTOPNOP
# ...

# %%
profile = ProfileReport(df, title='Reporte Eda')
profile.to_file("../reports/eda_original_dataframe.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 profile = ProfileReport(df, title='Reporte Eda')
# ----> 2 profile.to_file("reports/eda_original_dataframe.html")
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/site-packages/ydata_profiling/profile_report.py:395, in ProfileReport.to_file(self, output_file, silent)
#     391 disable_progress_bar = not self.config.progress_bar
#     392 with tqdm(
#     393     total=1, desc="Export report to file", disable=disable_progress_bar
#     394 ) as pbar:
# --> 395     output_file.write_text(data, encoding="utf-8")
#     396     pbar.update()
#     398 if not silent:
#
# File ~/.pyenv/versions/3.12.6/lib/python3.12/pathlib.py:1047, in Path.write_text(self, data, encoding, errors, newline)
# ...

# %%
df.to_csv("../dataFrames/data.csv", index=False)
