# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Load the CSV files
clean_data = pd.read_csv('datasets/cleanData.csv')

# Generate profile reports
clean_data_profile = ProfileReport(clean_data, title="Clean Data Profile", minimal=True)

# Save the reports to HTML files for comparison
clean_data_profile.to_file("reports/clean_data_dash_board.html")
# Out:
# 100%|██████████| 14/14 [00:00<00:00, 39542.26it/s]0:00, 50.69it/s, Describe variable: Reason for Reading]
# Summarize dataset: 100%|██████████| 20/20 [00:00<00:00, 69.64it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:05<00:00,  5.10s/it]
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  9.80it/s]
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 23.93it/s]
