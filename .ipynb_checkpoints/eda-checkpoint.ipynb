# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('datos.csv', sep=';')

# %%
# see
print(df.head())
print("\n")
# info
print(df.info())
# Out:
#    ID               Titulo            Genero Plataforma Fecha_Lanzamiento  \
# 0   1  THE LEGEND OF ZELDA          Aventura     Switch         3/03/2017
# 1   2           god of war            Acción        PS4        20/04/2018
# 2   3           God of War  Acción; Aventura        PS4        20/04/2018
# 3   4                  NaN               RPG         PC        10/12/2020
# 4   5            Minecraft           Sandbox        NaN        18/11/2011
#
#    Puntuacion        Desarrollador Precio_USD Multiplataforma Metascore  \
# 0         9.5             Nintendo      59.99              No        97
# 1         9.8         Santa Monica      39.99            true        94
# 2         9.8  Santa Monica Studio      39.99              Sí        94
# 3         7.0       CD Projekt Red      29.99             Yes        76
# 4         9.0               Mojang      26.95               Y        93
#
#    Unnamed: 10
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 100 non-null    int64
#  1   Titulo             85 non-null     object
#  2   Genero             100 non-null    object
#  3   Plataforma         99 non-null     object
#  4   Fecha_Lanzamiento  100 non-null    object
#  5   Puntuacion         100 non-null    float64
#  6   Desarrollador      95 non-null     object
#  7   Precio_USD         97 non-null     object
#  8   Multiplataforma    97 non-null     object
#  9   Metascore          95 non-null     object
#  10  Unnamed: 10        3 non-null      float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 8.7+ KB
# None

# %%
print(df.isnull().sum())
# Out:
# ID                    0
# Titulo               15
# Genero                0
# Plataforma            1
# Fecha_Lanzamiento     0
# Puntuacion            0
# Desarrollador         5
# Precio_USD            3
# Multiplataforma       3
# Metascore             5
# Unnamed: 10          97
# dtype: int64

# %%
def convertir_bool(valor):
    if isinstance(valor, str):
        valor = valor.strip().lower()
        return valor in ['yes', 'y','true','1', 'si']
    return bool(valor)
df['Multiplataforma'] = df['Multiplataforma'].apply(convertir_bool)
print(df['Multiplataforma'].head())
print("\n")
print(df['Multiplataforma'].info())
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: Multiplataforma, dtype: bool
#
#
# <class 'pandas.core.series.Series'>
# RangeIndex: 100 entries, 0 to 99
# Series name: Multiplataforma
# Non-Null Count  Dtype
# --------------  -----
# 100 non-null    bool
# dtypes: bool(1)
# memory usage: 232.0 bytes
# None

# %%
df['ID'] = df['ID'].astype(int)
df['Multiplataforma'] = df['Multiplataforma'].astype(bool)
text = ['Titulo', 'Genero','Plataforma','Fecha_Lanzamiento','Desarrollador']

for i in text:
    df[i] = df[i].astype('string')

numeric_cols = ['Puntuacion', 'Precio_USD', 'Metascore']
for i in numeric_cols:
    df[i] = pd.to_numeric(df[i], errors='coerce')

# %%
df.drop(columns=['Unnamed: 10'], inplace=True, errors='ignore')
df = df[df['Titulo'].notna()]
df['Plataforma'] = df['Plataforma'].fillna(df['Plataforma'].mode()[0])
df['Desarrollador'] = df['Desarrollador'].fillna('Desconocido')

df['Precio_USD'] = df['Precio_USD'].fillna(df['Precio_USD'].median())
df['Metascore'] = df['Metascore'].fillna(df['Metascore'].mean())

print(df.isnull().sum())
# Out:
# ID                   0
# Titulo               0
# Genero               0
# Plataforma           0
# Fecha_Lanzamiento    0
# Puntuacion           0
# Desarrollador        0
# Precio_USD           0
# Multiplataforma      0
# Metascore            0
# dtype: int64

# %%
# vamos a procesar los duplicados
print(df['Titulo'].str.lower().duplicated().sum())
df['titulo_minuscula'] = df['Titulo'].str.lower()

df.drop_duplicates(subset='titulo_minuscula', keep='first', inplace=True)

df.drop(columns='titulo_minuscula', inplace=True)
# Out:
# 0

# %%
df.head(100)
# Out:
#      ID               Titulo            Genero     Plataforma  \
# 0     1  THE LEGEND OF ZELDA          Aventura         Switch
# 1     2           god of war            Acción            PS4
# 2     3           God of War  Acción; Aventura            PS4
# 4     5            Minecraft           Sandbox            PS4
# 5     6        The Witcher 3               RPG            PS4
# ..  ...                  ...               ...            ...
# 94   95         Call of Duty               FPS  Multiplatform
# 95   96          Overwatch 2           Shooter             PC
# 96   97           Elden Ring               RPG            PS5
# 98   99              FIFA 23          Football            PS5
# 99  100       Cyberpunk 2077               RPG             PC
#
#    Fecha_Lanzamiento  Puntuacion           Desarrollador  Precio_USD  \
# 0          3/03/2017         9.5                Nintendo       59.99
# 1         20/04/2018         9.8            Santa Monica       39.99
# 2         20/04/2018         9.8     Santa Monica Studio       39.99
# 4         18/11/2011         9.0                  Mojang       26.95
# 5             may-19      2015.0                     9.7       49.99
# ..               ...         ...                     ...         ...
# 94        10/03/2020         8.0           Infinity Ward        0.00
# 95         4/10/2022         6.5  Blizzard Entertainment       49.99
# 96        25/02/2022         9.5            FromSoftware       59.99
# 98        30/09/2022         8.0            EA Vancouver       59.99
# 99        10/12/2020         7.0          CD Projekt Red       29.99
#
#     Multiplataforma  Metascore
# 0             False  97.000000
# 1              True  94.000000
# 2             False  94.000000
# 4              True  93.000000
# 5              True  87.268293
# ..              ...        ...
# 94             True  79.000000
# 95             True  68.000000
# 96            False  96.000000
# 98             True  76.000000
# 99            False  76.000000
#
# [85 rows x 10 columns]

# %%
df.to_csv('datosClean.csv', index=False)
